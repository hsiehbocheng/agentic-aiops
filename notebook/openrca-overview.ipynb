# %%
import pathlib
import pandas as pd

# %%
telemetry_dir = '../agent-eval/datasets/OpenRCA/Bank/telemetry'
date = '2021_03_06'

query_dir = '../agent-eval/datasets/OpenRCA/Bank/query.csv'
record_dir = '../agent-eval/datasets/OpenRCA/Bank/record.csv'
# log_dir = pathlib.Path(telemetry_dir) / date / 'log/log_service.csv'
# metric_app_dir = pathlib.Path(telemetry_dir) / date / 'metric/metric_app.csv'
# metric_container_dir = pathlib.Path(telemetry_dir) / date / 'metric/metric_container.csv'
# trace_dir = pathlib.Path(telemetry_dir) / date / 'trace/trace_span.csv'
